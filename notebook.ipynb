# %%
import desci.fetch as desci

with desci.fetch([('hello.py', 'say')], "m65VMjoNiL58USLdYGr27f_W_9Atwln04XsWlHISQYQ/0/1/!"):
    import say
    print(str.upper(say.hello()) + " world!")

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import desci.fetch as desci


with desci.fetch([('mandelbrot.py', 'mandelbrot')], "m65VMjoNiL58USLdYGr27f_W_9Atwln04XsWlHISQYQ/0/2/!"):
    import mandelbrot
    iterate_max = 300; center = (2.2, 1.5); scale = 3.0/800.0; Nx = 500
    xmin=386.5; xmax=388.5; ymin=421; ymax=425

    x,y,fractal = mandelbrot.calculate_mandelbrot_image(xmin,xmax,Nx,ymin,ymax,iterate_max,center,scale)
    C = np.power(np.real(fractal),0.5)

    fig = plt.figure()
    ax = fig.add_subplot(111)
    plt.pcolor(y,-x,np.abs(C),cmap=plt.cm.Blues_r)
    ax.set_aspect('equal')
